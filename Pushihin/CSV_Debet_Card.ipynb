# %%
import pandas as pd

# %%
data = pd.read_csv('Raw_data.csv')

# %%
data
# Out:
#                                client_id gender  birth_date create_date  \
# 0       fe60b594364f9f636266ed1ef4f89c32      Ж        1985  2020-01-29
# 1       3012cabca5885ed53d348d6e57dab5de      М        1951  2009-09-24
# 2       d871ef96820b6c7a1ada8e01a772724e      Ж        1982  2006-12-25
# 3       0bacbc2abd314f9fac031d249e485a7b      М        1955  2011-04-15
# 4       0bacbc2abd314f9fac031d249e485a7b      М        1955  2011-04-15
# ...                                  ...    ...         ...         ...
# 371578  d69d3201104ab393c0638839a7284ad7      М        1953  2018-08-08
# 371579  a936fb30e2268d2874cdcaa221032915      М        1997  2022-05-12
# 371580  a9cf0bb4f06fa321704ced777e993b33      М        1983  2021-10-15
# 371581  f69eb17242ca85eb21349dc08220afb8      Ж        1986  2022-02-12
# 371582  93237191eddf8dec77cc947c3c086358      Ж        1959  2012-07-19
#
#        nonresident_flag  businessman_flag              city  term  \
# 0                     R                 0  Гусь-Хрустальный   NaN
# 1                     R                 0           Ишимбай   NaN
# 2                     R                 0              Юрга   NaN
# 3                     R                 0             Томск   NaN
# 4                     R                 0             Томск   NaN
# ...                 ...               ...               ...   ...
# 371578                R                 0         Пятигорск   NaN
# 371579                R                 0          Кемерово   NaN
# 371580                R                 0   Санкт-Петербург   NaN
# 371581                R                 0               Уфа   NaN
# 371582                R                 0            Москва   NaN
#
#         contract_sum                        product_category_name  ...  \
# 0                0.0  Договор на текущий счет для дебетовой карты  ...
# 1                0.0  Договор на текущий счет для дебетовой карты  ...
# 2                0.0  Договор на текущий счет для дебетовой карты  ...
# 3                0.0  Договор на текущий счет для дебетовой карты  ...
# 4                0.0  Договор на текущий счет для дебетовой карты  ...
# ...              ...                                          ...  ...
# 371578      200000.0                              Кредитная карта  ...
# 371579       15000.0                              Кредитная карта  ...
# 371580       15000.0                              Кредитная карта  ...
# 371581       15000.0                              Кредитная карта  ...
# 371582       30000.0                              Кредитная карта  ...
#
#                    card_type_name start_date  fact_close_date  purchase_sum  \
# 0           Visa Platinum Rewards     2019.0           2021.0       16600.0
# 1                    VISA Classic     2019.0              NaN           0.0
# 2                             NaN        NaN              NaN           0.0
# 3                    Visa Rewards     2021.0              NaN       24300.0
# 4       Eurocard/MasterCard World     2018.0           2022.0       24300.0
# ...                           ...        ...              ...           ...
# 371578                        NaN        NaN              NaN           0.0
# 371579                        NaN        NaN              NaN       15000.0
# 371580                        NaN        NaN              NaN         600.0
# 371581                        NaN        NaN              NaN           0.0
# 371582                        NaN        NaN              NaN        9900.0
#
#         purchase_count  current_balance_avg_sum  current_balance_sum  \
# 0                   71                  39700.0              25700.0
# 1                    0                   1900.0               1000.0
# 2                    0                      0.0                  0.0
# 3                  118                      0.0                  0.0
# 4                  118                      0.0                  0.0
# ...                ...                      ...                  ...
# 371578               0                      0.0                300.0
# 371579              33                      0.0                  0.0
# 371580               5                      0.0                  0.0
# 371581               0                      0.0                  0.0
# 371582              19                      0.0                  0.0
#
#         current_debit_turn_sum  current_credit_turn_sum  card_type
# 0                     220600.0                 201000.0         dc
# 1                       6200.0                   3000.0         dc
# 2                          0.0                      0.0         dc
# 3                      35400.0                  35400.0         cc
# 4                      35400.0                  35400.0         cc
# ...                        ...                      ...        ...
# 371578                  9900.0                  10100.0         dc
# 371579                 15000.0                  15000.0         dc
# 371580                  1100.0                   1100.0         dc
# 371581                  1100.0                   1100.0         dc
# 371582                 29900.0                  29900.0         dc
#
# [371583 rows x 21 columns]

# %%
data.shape
# Out:
# (371583, 21)

# %% [markdown]
# Подготовка базы данных

# %%
data = data.drop(['term','businessman_flag'], axis=1)

# %%
data = data.fillna({'start_date': -1, 'fact_close_date': -1})

# %%
data = data.astype({'start_date': int, 'fact_close_date': int , 'purchase_sum':int ,'purchase_sum':int ,'contract_sum':int , 'current_balance_avg_sum':int , 'current_balance_sum':int, 'current_debit_turn_sum':int, 'current_credit_turn_sum':int})

# %%
data.shape
# Out:
# (371583, 19)

# %%
a = data['card_id'].value_counts()
a
# Out:
# 899e767a957c195ed319a58238474242    39
# bb609973024e83acdc33b86518958f8b    25
# 8a259e220b3e37c8eaffc29527d5ade6    25
# a1eaf5482998db17b0643c785282f24c    24
# f22ad7a6a51f9f35ab56f0baafc64580    24
#                                     ..
# bcfd99a051ed8d72c4259be0b9df9b0c     1
# ae777bff43479b2a7dcc511046e77b8d     1
# be76733d780bf1a87603fc28cb5bbe7d     1
# 5b35221a74880f4ed56dc6c95a6c1d50     1
# db7d3058f19b8bab645cf33efd86330d     1
# Name: card_id, Length: 22583, dtype: int64

# %%
data
# Out:
#                                client_id gender  birth_date create_date  \
# 0       fe60b594364f9f636266ed1ef4f89c32      Ж        1985  2020-01-29
# 1       3012cabca5885ed53d348d6e57dab5de      М        1951  2009-09-24
# 2       d871ef96820b6c7a1ada8e01a772724e      Ж        1982  2006-12-25
# 3       0bacbc2abd314f9fac031d249e485a7b      М        1955  2011-04-15
# 4       0bacbc2abd314f9fac031d249e485a7b      М        1955  2011-04-15
# ...                                  ...    ...         ...         ...
# 371578  d69d3201104ab393c0638839a7284ad7      М        1953  2018-08-08
# 371579  a936fb30e2268d2874cdcaa221032915      М        1997  2022-05-12
# 371580  a9cf0bb4f06fa321704ced777e993b33      М        1983  2021-10-15
# 371581  f69eb17242ca85eb21349dc08220afb8      Ж        1986  2022-02-12
# 371582  93237191eddf8dec77cc947c3c086358      Ж        1959  2012-07-19
#
#        nonresident_flag              city  contract_sum  \
# 0                     R  Гусь-Хрустальный             0
# 1                     R           Ишимбай             0
# 2                     R              Юрга             0
# 3                     R             Томск             0
# 4                     R             Томск             0
# ...                 ...               ...           ...
# 371578                R         Пятигорск        200000
# 371579                R          Кемерово         15000
# 371580                R   Санкт-Петербург         15000
# 371581                R               Уфа         15000
# 371582                R            Москва         30000
#
#                               product_category_name  \
# 0       Договор на текущий счет для дебетовой карты
# 1       Договор на текущий счет для дебетовой карты
# 2       Договор на текущий счет для дебетовой карты
# 3       Договор на текущий счет для дебетовой карты
# 4       Договор на текущий счет для дебетовой карты
# ...                                             ...
# 371578                              Кредитная карта
# 371579                              Кредитная карта
# 371580                              Кредитная карта
# 371581                              Кредитная карта
# 371582                              Кредитная карта
#
#                                  card_id             card_type_name  \
# 0       a83cbc33f164deae41b3339141923cc7      Visa Platinum Rewards
# 1       8dae17a830bb05d151034df618efbcad               VISA Classic
# 2       429ca8c43cdc5f3d8c9efc9069ee3fa6                        NaN
# 3       e7f4adb9187b867ebea15503298437a3               Visa Rewards
# 4       e7d13882154e965dca7070eb8d626f77  Eurocard/MasterCard World
# ...                                  ...                        ...
# 371578  a78c73e84e893179de17071583cf5084                        NaN
# 371579  e3304eaf55891a175b6abf8030b99da1                        NaN
# 371580  c53331e855fdda10b01fa1b11d96292c                        NaN
# 371581  fe20a230ac51078059b03220558ed853                        NaN
# 371582  db7d3058f19b8bab645cf33efd86330d                        NaN
#
#         start_date  fact_close_date  purchase_sum  purchase_count  \
# 0             2019             2021         16600              71
# 1             2019               -1             0               0
# 2               -1               -1             0               0
# 3             2021               -1         24300             118
# 4             2018             2022         24300             118
# ...            ...              ...           ...             ...
# 371578          -1               -1             0               0
# 371579          -1               -1         15000              33
# 371580          -1               -1           600               5
# 371581          -1               -1             0               0
# 371582          -1               -1          9900              19
#
#         current_balance_avg_sum  current_balance_sum  current_debit_turn_sum  \
# 0                         39700                25700                  220600
# 1                          1900                 1000                    6200
# 2                             0                    0                       0
# 3                             0                    0                   35400
# 4                             0                    0                   35400
# ...                         ...                  ...                     ...
# 371578                        0                  300                    9900
# 371579                        0                    0                   15000
# 371580                        0                    0                    1100
# 371581                        0                    0                    1100
# 371582                        0                    0                   29900
#
#         current_credit_turn_sum card_type
# 0                        201000        dc
# 1                          3000        dc
# 2                             0        dc
# 3                         35400        cc
# 4                         35400        cc
# ...                         ...       ...
# 371578                    10100        dc
# 371579                    15000        dc
# 371580                     1100        dc
# 371581                     1100        dc
# 371582                    29900        dc
#
# [371583 rows x 19 columns]

# %%
data = data.drop_duplicates() # Избавление от дубликатов записей

# %%
a = data['card_id'].value_counts()
a
# Out:
# 899e767a957c195ed319a58238474242    39
# bb609973024e83acdc33b86518958f8b    25
# 8a259e220b3e37c8eaffc29527d5ade6    25
# a1eaf5482998db17b0643c785282f24c    24
# f22ad7a6a51f9f35ab56f0baafc64580    24
#                                     ..
# bcfd99a051ed8d72c4259be0b9df9b0c     1
# ae777bff43479b2a7dcc511046e77b8d     1
# be76733d780bf1a87603fc28cb5bbe7d     1
# 5b35221a74880f4ed56dc6c95a6c1d50     1
# db7d3058f19b8bab645cf33efd86330d     1
# Name: card_id, Length: 22583, dtype: int64

# %%
data.shape
# Out:
# (240397, 19)

# %% [markdown]
# Поиск актуальных записей

# %%
listUniqueCardID = data.card_id.unique()
len(listUniqueCardID)
# Out:
# 22583

# %%
import threading
import sys

# %%
def getlistEqualPartsOfNumberParts(intNub, intParts):
  d, r = divmod(intNub, intParts)
  return [d + (1 if i < r else 0) for i in range(intParts)]

# %%
def th_get_ActualUserData(gl_DataFrame, listUniqueCardID, intIndex):
    local_UsersData = pd.DataFrame()
    for i in range(len(listUniqueCardID)):
        if float(i%100) == 0:
            print(i)
            
        strPDCall = f"card_id == '{listUniqueCardID[i]}'" # Запрос

        #f_Data = data.query(strPDCall)
        #print( listUniqueCardID[i] , '-', f_Data.shape)

        local_Data = data.query(strPDCall).drop_duplicates()
        #print( listUniqueCardID[i] , '---', local_Data.shape,'\n')

        if (local_Data.shape[0] != 1):
              
            maxDebet =  local_Data['current_debit_turn_sum'].max()
            maxCredet = local_Data['current_credit_turn_sum'].max()
            
            thisDB = local_Data.query(f"current_debit_turn_sum == {maxDebet} & current_credit_turn_sum == {maxCredet}")
            
        else:
            thisDB = local_Data
        
        #print(i, "-", thisDB.shape, "-", listUniqueCardID[i],'\n')

        local_UsersData = pd.concat([local_UsersData, thisDB]) 
           
        #print(local_UsersData.shape)

    local_UsersData.to_csv(f'New_CSV_{intIndex}.csv')

    gl_DataFrame = pd.concat([gl_DataFrame, local_UsersData]) 
    print(gl_DataFrame.shape)

    print(f'Thread {intIndex} is done !')
    sys.exit

# %%
listParts = getlistEqualPartsOfNumberParts(len(listUniqueCardID),int(len(listUniqueCardID)/500))
listThreads = []
intCount = 0

for i in range(len(listParts)):

    if listParts[i] == 0 :
        break
    print(f'Thread {i} from {intCount} to {intCount+listParts[i]} is start - {listParts[i]}')
    listThreads.append( threading.Thread( name=f'Thread_{i}', target=th_get_ActualUserData, args=(gl_ActualUserData, listUniqueCardID[ intCount: intCount+listParts[i] ],i , ) ))
    intCount += listParts[i]+1
    listThreads[i].start()

# %%
gl_ActualUserData = pd.DataFrame()

for i in range(len(listParts)):
    gl_ActualUserData = pd.concat([gl_ActualUserData, pd.read_csv(f'Source_f_2/New_CSV_{i}.csv').drop_duplicates()]) 
gl_ActualUserData.shape
# Out:
# (16313, 20)

# %%
count = 0
for i in range(len(listParts)):
    count += pd.read_csv(f'Source_f_2/New_CSV_{i}.csv').shape[0]
count
# Out:
# 16313

# %%
gl_ActualUserData
# Out:
#      Unnamed: 0                         client_id gender  birth_date  \
# 0             0  fe60b594364f9f636266ed1ef4f89c32      Ж        1985
# 1        237315  3012cabca5885ed53d348d6e57dab5de      М        1951
# 2             2  d871ef96820b6c7a1ada8e01a772724e      Ж        1982
# 3        131863  0bacbc2abd314f9fac031d249e485a7b      М        1955
# 4        131864  0bacbc2abd314f9fac031d249e485a7b      М        1955
# ..          ...                               ...    ...         ...
# 325      371570  9acb18399b830419bac9653b52754646      М        1986
# 326      371577  8b3206ca8d77aa2446824971f47c531b      Ж        1996
# 327      371578  d69d3201104ab393c0638839a7284ad7      М        1953
# 328      371579  a936fb30e2268d2874cdcaa221032915      М        1997
# 329      371582  93237191eddf8dec77cc947c3c086358      Ж        1959
#
#     create_date nonresident_flag              city  contract_sum  \
# 0    2020-01-29                R  Гусь-Хрустальный             0
# 1    2009-09-24                R           Ишимбай             0
# 2    2006-12-25                R              Юрга             0
# 3    2011-04-15                R             Томск             0
# 4    2011-04-15                R             Томск             0
# ..          ...              ...               ...           ...
# 325  2015-05-20                R               Уфа             0
# 326  2022-04-28                R            Казань         30000
# 327  2018-08-08                R         Пятигорск        200000
# 328  2022-05-12                R          Кемерово         15000
# 329  2012-07-19                R            Москва         30000
#
#                            product_category_name  \
# 0    Договор на текущий счет для дебетовой карты
# 1    Договор на текущий счет для дебетовой карты
# 2    Договор на текущий счет для дебетовой карты
# 3    Договор на текущий счет для дебетовой карты
# 4    Договор на текущий счет для дебетовой карты
# ..                                           ...
# 325  Договор на текущий счет для дебетовой карты
# 326                              Кредитная карта
# 327                              Кредитная карта
# 328                              Кредитная карта
# 329                              Кредитная карта
#
#                               card_id             card_type_name  start_date  \
# 0    a83cbc33f164deae41b3339141923cc7      Visa Platinum Rewards        2019
# 1    8dae17a830bb05d151034df618efbcad               VISA Classic        2019
# 2    429ca8c43cdc5f3d8c9efc9069ee3fa6                        NaN          -1
# 3    e7f4adb9187b867ebea15503298437a3               Visa Rewards        2021
# 4    e7d13882154e965dca7070eb8d626f77  Eurocard/MasterCard World        2018
# ..                                ...                        ...         ...
# 325  d090cb20c22e2643ec366daf8d26d646                        NaN          -1
# 326  5a0041efbd5832765caf8b9f861bffa3                        NaN          -1
# 327  a78c73e84e893179de17071583cf5084                        NaN          -1
# 328  e3304eaf55891a175b6abf8030b99da1                        NaN          -1
# 329  db7d3058f19b8bab645cf33efd86330d                        NaN          -1
#
#      fact_close_date  purchase_sum  purchase_count  current_balance_avg_sum  \
# 0               2021         16600              71                    39700
# 1                 -1          4900               2                    38000
# 2                 -1             0               0                        0
# 3                 -1         47800              12                        0
# 4               2022         47800              12                        0
# ..               ...           ...             ...                      ...
# 325               -1             0               0                        0
# 326               -1         22700               7                        0
# 327               -1             0               0                        0
# 328               -1         15000              33                        0
# 329               -1          9900              19                        0
#
#      current_balance_sum  current_debit_turn_sum  current_credit_turn_sum  \
# 0                  25700                  220600                   201000
# 1                  26800                   56300                    31300
# 2                      0                       0                        0
# 3                      0                   51500                    51500
# 4                      0                   51500                    51500
# ..                   ...                     ...                      ...
# 325                    0                       0                        0
# 326                    0                   22700                    22700
# 327                  300                    9900                    10100
# 328                    0                   15000                    15000
# 329                    0                   29900                    29900
#
#     card_type
# 0          dc
# 1          dc
# 2          dc
# 3          cc
# 4          cc
# ..        ...
# 325        dc
# 326        dc
# 327        dc
# 328        dc
# 329        dc
#
# [16313 rows x 20 columns]

# %%
gl_ActualUserData.drop(['Unnamed: 0'], axis=1)
# Out:
#                             client_id gender  birth_date create_date  \
# 0    fe60b594364f9f636266ed1ef4f89c32      Ж        1985  2020-01-29
# 1    3012cabca5885ed53d348d6e57dab5de      М        1951  2009-09-24
# 2    d871ef96820b6c7a1ada8e01a772724e      Ж        1982  2006-12-25
# 3    0bacbc2abd314f9fac031d249e485a7b      М        1955  2011-04-15
# 4    0bacbc2abd314f9fac031d249e485a7b      М        1955  2011-04-15
# ..                                ...    ...         ...         ...
# 325  9acb18399b830419bac9653b52754646      М        1986  2015-05-20
# 326  8b3206ca8d77aa2446824971f47c531b      Ж        1996  2022-04-28
# 327  d69d3201104ab393c0638839a7284ad7      М        1953  2018-08-08
# 328  a936fb30e2268d2874cdcaa221032915      М        1997  2022-05-12
# 329  93237191eddf8dec77cc947c3c086358      Ж        1959  2012-07-19
#
#     nonresident_flag              city  contract_sum  \
# 0                  R  Гусь-Хрустальный             0
# 1                  R           Ишимбай             0
# 2                  R              Юрга             0
# 3                  R             Томск             0
# 4                  R             Томск             0
# ..               ...               ...           ...
# 325                R               Уфа             0
# 326                R            Казань         30000
# 327                R         Пятигорск        200000
# 328                R          Кемерово         15000
# 329                R            Москва         30000
#
#                            product_category_name  \
# 0    Договор на текущий счет для дебетовой карты
# 1    Договор на текущий счет для дебетовой карты
# 2    Договор на текущий счет для дебетовой карты
# 3    Договор на текущий счет для дебетовой карты
# 4    Договор на текущий счет для дебетовой карты
# ..                                           ...
# 325  Договор на текущий счет для дебетовой карты
# 326                              Кредитная карта
# 327                              Кредитная карта
# 328                              Кредитная карта
# 329                              Кредитная карта
#
#                               card_id             card_type_name  start_date  \
# 0    a83cbc33f164deae41b3339141923cc7      Visa Platinum Rewards        2019
# 1    8dae17a830bb05d151034df618efbcad               VISA Classic        2019
# 2    429ca8c43cdc5f3d8c9efc9069ee3fa6                        NaN          -1
# 3    e7f4adb9187b867ebea15503298437a3               Visa Rewards        2021
# 4    e7d13882154e965dca7070eb8d626f77  Eurocard/MasterCard World        2018
# ..                                ...                        ...         ...
# 325  d090cb20c22e2643ec366daf8d26d646                        NaN          -1
# 326  5a0041efbd5832765caf8b9f861bffa3                        NaN          -1
# 327  a78c73e84e893179de17071583cf5084                        NaN          -1
# 328  e3304eaf55891a175b6abf8030b99da1                        NaN          -1
# 329  db7d3058f19b8bab645cf33efd86330d                        NaN          -1
#
#      fact_close_date  purchase_sum  purchase_count  current_balance_avg_sum  \
# 0               2021         16600              71                    39700
# 1                 -1          4900               2                    38000
# 2                 -1             0               0                        0
# 3                 -1         47800              12                        0
# 4               2022         47800              12                        0
# ..               ...           ...             ...                      ...
# 325               -1             0               0                        0
# 326               -1         22700               7                        0
# 327               -1             0               0                        0
# 328               -1         15000              33                        0
# 329               -1          9900              19                        0
#
#      current_balance_sum  current_debit_turn_sum  current_credit_turn_sum  \
# 0                  25700                  220600                   201000
# 1                  26800                   56300                    31300
# 2                      0                       0                        0
# 3                      0                   51500                    51500
# 4                      0                   51500                    51500
# ..                   ...                     ...                      ...
# 325                    0                       0                        0
# 326                    0                   22700                    22700
# 327                  300                    9900                    10100
# 328                    0                   15000                    15000
# 329                    0                   29900                    29900
#
#     card_type
# 0          dc
# 1          dc
# 2          dc
# 3          cc
# 4          cc
# ..        ...
# 325        dc
# 326        dc
# 327        dc
# 328        dc
# 329        dc
#
# [16313 rows x 19 columns]

# %%
#listThreads = []
#listThreads.append( threading.Thread( target=th_get_ActualUserData, args=(gl_ActualUserData, listUniqueCardID[ 0: 500],1 , ) ))
#listThreads[0].start()

# %%
gl_ActualUserData.to_csv('RTG_CSV.csv')

# %% [markdown]
# Мужчины / Женщины

# %%
ManToWoman = gl_ActualUserData.drop_duplicates(subset=['client_id'])
ManToWoman = ManToWoman['gender'].value_counts()

# %%
ManToWoman = ManToWoman.to_frame()
ManToWoman = ManToWoman.rename(columns = {0:'gender', 1:'count'})
ManToWoman
# Out:
#    gender
# Ж    6340
# М    5716

# %%
ManToWoman.to_json('ManToWoman.json')

# %% [markdown]
# Количество приобретённых карт за год

# %%
import datetime

now = datetime.datetime.now()

# %%
cardTypeDF = gl_ActualUserData.query(f"start_date >= {now.year}-1")
cardTypeDF
# Out:
#      Unnamed: 0                         client_id gender  birth_date  \
# 3        131863  0bacbc2abd314f9fac031d249e485a7b      М        1955
# 7        211127  069a78f2b5f78554eaa5dbb61d84fc24      Ж        1960
# 10        29471  f15f2554a0ce062adfb77b89583f312f      М        1989
# 17       235936  c0558c09e6d8967a4f7da4e631af0931      Ж        1992
# 24       209966  b6bdc6ad9870be654af83757cc1e1823      Ж        1993
# ..          ...                               ...    ...         ...
# 317      371362  6c3347ad0cc240e20366a1a0b09bca0a      М        1970
# 318      371357  984e5ad59b98958dde5b395011852abc      Ж        1996
# 321      371431  bc661fc9c5da2c9aa896e45ea668ba06      М        1973
# 323      371486  66a3d5e9a035415aaa39298bf5f13a03      М        1989
# 324      371569  a5aa5918ab2d581c3584e712ecf503f4      М        1997
#
#     create_date nonresident_flag             city  contract_sum  \
# 3    2011-04-15                R            Томск             0
# 7    2018-08-17                R  Нижний Новгород             0
# 10   2010-12-16                R           Туапсе             0
# 17   2018-02-09                R              Уфа             0
# 24   2011-09-13                R              Уфа             0
# ..          ...              ...              ...           ...
# 317  2020-06-11                R              Уфа             0
# 318  2022-02-16                R              Уфа             0
# 321  2013-04-17                R         Смоленск             0
# 323  2018-12-12                R           Москва             0
# 324  2018-06-14                R           Москва             0
#
#                            product_category_name  \
# 3    Договор на текущий счет для дебетовой карты
# 7    Договор на текущий счет для дебетовой карты
# 10   Договор на текущий счет для дебетовой карты
# 17   Договор на текущий счет для дебетовой карты
# 24   Договор на текущий счет для дебетовой карты
# ..                                           ...
# 317  Договор на текущий счет для дебетовой карты
# 318  Договор на текущий счет для дебетовой карты
# 321  Договор на текущий счет для дебетовой карты
# 323  Договор на текущий счет для дебетовой карты
# 324  Договор на текущий счет для дебетовой карты
#
#                               card_id                  card_type_name  \
# 3    e7f4adb9187b867ebea15503298437a3                    Visa Rewards
# 7    179c20dc702f8b3553b10e1b083cc8b9              VISA Classic Light
# 10   bae6632af4c6d36013a6a6a594a261d6        Eurocard/MasterCard Mass
# 17   29aef8d895f0ba76f3493b58996acd89                       МИР Debit
# 24   36d2401aee9a26300691fefba9b31ff7  Дебет карта ПС МИР "Бюджетная"
# ..                                ...                             ...
# 317  dccd72269a1b128a42c18e61f9f70cf6                      МИР СКБ ЗП
# 318  615d994b55876b010020388483901006           MasterCard Electronic
# 321  53aa0c8480996c8773abff9bc263c903  Дебет карта ПС МИР "Бюджетная"
# 323  d26bfffaeeaad088cdcd7d5d6135a4e3              MIR Privilege Plus
# 324  9688af6309629f15b8f9890e9a6b5416              MIR Privilege Plus
#
#      start_date  fact_close_date  purchase_sum  purchase_count  \
# 3          2021               -1         47800              12
# 7          2021               -1           100               2
# 10         2021               -1          9100              23
# 17         2021               -1          1100               1
# 24         2021               -1             0               0
# ..          ...              ...           ...             ...
# 317        2022               -1             0               0
# 318        2022               -1          3600              17
# 321        2022               -1          2100               7
# 323        2022               -1             0               0
# 324        2022               -1             0               0
#
#      current_balance_avg_sum  current_balance_sum  current_debit_turn_sum  \
# 3                          0                    0                   51500
# 7                       2700                 4100                   11100
# 10                     32700                50200                  110400
# 17                       400                    0                    2900
# 24                      2600                40000                   66600
# ..                       ...                  ...                     ...
# 317                     6800                15600                       0
# 318                      400                    0                   11900
# 321                      600                  400                    2100
# 323                     6500               100000                       0
# 324                        0                    0                       0
#
#      current_credit_turn_sum card_type
# 3                      51500        cc
# 7                      10100        dc
# 10                    151900        dc
# 17                      2900        dc
# 24                    106600        dc
# ..                       ...       ...
# 317                    15600        dc
# 318                    11500        dc
# 321                     2000        dc
# 323                   100000        dc
# 324                        0        dc
#
# [5461 rows x 20 columns]

# %%
cardTypeDF.isnull().sum()
# Out:
# Unnamed: 0                  0
# client_id                   0
# gender                      0
# birth_date                  0
# create_date                 0
# nonresident_flag            0
# city                       56
# contract_sum                0
# product_category_name       0
# card_id                     0
# card_type_name              0
# start_date                  0
# fact_close_date             0
# purchase_sum                0
# purchase_count              0
# current_balance_avg_sum     0
# current_balance_sum         0
# current_debit_turn_sum      0
# current_credit_turn_sum     0
# card_type                   0
# dtype: int64

# %%
listCardType = cardTypeDF['card_type_name'].unique()
listCardType
# Out:
# array(['Visa Rewards', 'VISA Classic Light', 'Eurocard/MasterCard Mass',
#        'МИР Debit', 'Дебет карта ПС МИР "Бюджетная"', 'VISA Classic',
#        'МИР СКБ', 'Eurocard/MasterCard Platinum', 'МИР СКБ ЗП',
#        'Eurocard/MasterCard World', 'Eurocard/MasterCard Gold',
#        'VISA Gold', 'Priority Pass', 'MasterCard World Elite',
#        'MasterCard Electronic', 'Visa Platinum Rewards', 'VISA Infinite',
#        'MasterCard Black Edition', 'VISA Platinum', 'МИР Копилка',
#        'Eurocard/MasterCard Virt', 'Visa Signature', 'MIR Supreme',
#        'MIR Privilege Plus'], dtype=object)

# %%
cardTypeDF = cardTypeDF['card_type_name'].value_counts()
cardTypeDF
# Out:
# Visa Platinum Rewards             1247
# Visa Rewards                      1062
# Дебет карта ПС МИР "Бюджетная"     611
# МИР Debit                          520
# VISA Classic                       355
# VISA Gold                          246
# Eurocard/MasterCard Mass           211
# VISA Classic Light                 174
# МИР СКБ                            164
# Eurocard/MasterCard World          157
# MasterCard Electronic              136
# МИР СКБ ЗП                         131
# Eurocard/MasterCard Platinum       118
# Priority Pass                       72
# MasterCard World Elite              58
# Eurocard/MasterCard Gold            54
# VISA Infinite                       40
# MIR Supreme                         32
# Visa Signature                      25
# MIR Privilege Plus                  20
# VISA Platinum                       13
# MasterCard Black Edition            10
# Eurocard/MasterCard Virt             4
# МИР Копилка                          1
# Name: card_type_name, dtype: int64

# %%
sum = cardTypeDF.values.sum()
sum
# Out:
# 5461

# %%
listCreditSys = ['Visa','MIR','МИР','MasterCard','Maestro']
listCreditSysCount = [0]*len(listCreditSys)
print(listCreditSysCount)
# Out:
# [0, 0, 0, 0, 0]

# %%
print('Visa' in "Visa Signature")
print('MIR' in "Visa Signature")
print('Visa'.capitalize() in "Visa Signature")
# Out:
# True
# False
# True

# %%
for i in range(len(cardTypeDF.index)):
    for j in range(len(listCreditSys)):
        if (listCreditSys[j] in cardTypeDF.index[i]) or (listCreditSys[j] in cardTypeDF.index[i].capitalize()):
            listCreditSysCount[j] += cardTypeDF.values[i]
print(listCreditSys)
print(listCreditSysCount)
# Out:
# ['Visa', 'MIR', 'МИР', 'MasterCard', 'Maestro']
# [3162, 52, 1427, 748, 0]

# %%
list_tuples  = list(zip(listCreditSys, listCreditSysCount))
NewBankCard = pd.DataFrame(list_tuples, columns=['listCreditSys', 'listCreditSysCount']) 
NewBankCard.to_json('NewBankCard.json')

# %% [markdown]
# Кол-во действующих банковских карт

# %%
ValueCardData = gl_ActualUserData.query(f"start_date != -1 & fact_close_date == -1")
ValueCardData
# Out:
#      Unnamed: 0                         client_id gender  birth_date  \
# 1        237315  3012cabca5885ed53d348d6e57dab5de      М        1951
# 3        131863  0bacbc2abd314f9fac031d249e485a7b      М        1955
# 5             5  c79f7d18334216f7bd6c40a05e4a0335      Ж        1980
# 7        211127  069a78f2b5f78554eaa5dbb61d84fc24      Ж        1960
# 9         29470  f15f2554a0ce062adfb77b89583f312f      М        1989
# ..          ...                               ...    ...         ...
# 317      371362  6c3347ad0cc240e20366a1a0b09bca0a      М        1970
# 318      371357  984e5ad59b98958dde5b395011852abc      Ж        1996
# 321      371431  bc661fc9c5da2c9aa896e45ea668ba06      М        1973
# 323      371486  66a3d5e9a035415aaa39298bf5f13a03      М        1989
# 324      371569  a5aa5918ab2d581c3584e712ecf503f4      М        1997
#
#     create_date nonresident_flag             city  contract_sum  \
# 1    2009-09-24                R          Ишимбай             0
# 3    2011-04-15                R            Томск             0
# 5    2015-06-19                R      Октябрьский             0
# 7    2018-08-17                R  Нижний Новгород             0
# 9    2010-12-16                R           Туапсе             0
# ..          ...              ...              ...           ...
# 317  2020-06-11                R              Уфа             0
# 318  2022-02-16                R              Уфа             0
# 321  2013-04-17                R         Смоленск             0
# 323  2018-12-12                R           Москва             0
# 324  2018-06-14                R           Москва             0
#
#                            product_category_name  \
# 1    Договор на текущий счет для дебетовой карты
# 3    Договор на текущий счет для дебетовой карты
# 5    Договор на текущий счет для дебетовой карты
# 7    Договор на текущий счет для дебетовой карты
# 9    Договор на текущий счет для дебетовой карты
# ..                                           ...
# 317  Договор на текущий счет для дебетовой карты
# 318  Договор на текущий счет для дебетовой карты
# 321  Договор на текущий счет для дебетовой карты
# 323  Договор на текущий счет для дебетовой карты
# 324  Договор на текущий счет для дебетовой карты
#
#                               card_id                  card_type_name  \
# 1    8dae17a830bb05d151034df618efbcad                    VISA Classic
# 3    e7f4adb9187b867ebea15503298437a3                    Visa Rewards
# 5    e3baaf11e34b13c3cbb93fd6e2f6096e                       МИР Debit
# 7    179c20dc702f8b3553b10e1b083cc8b9              VISA Classic Light
# 9    ca3b0bab14de9b04132ecb84c2b01f6c        Eurocard/MasterCard Mass
# ..                                ...                             ...
# 317  dccd72269a1b128a42c18e61f9f70cf6                      МИР СКБ ЗП
# 318  615d994b55876b010020388483901006           MasterCard Electronic
# 321  53aa0c8480996c8773abff9bc263c903  Дебет карта ПС МИР "Бюджетная"
# 323  d26bfffaeeaad088cdcd7d5d6135a4e3              MIR Privilege Plus
# 324  9688af6309629f15b8f9890e9a6b5416              MIR Privilege Plus
#
#      start_date  fact_close_date  purchase_sum  purchase_count  \
# 1          2019               -1          4900               2
# 3          2021               -1         47800              12
# 5          2019               -1             0               0
# 7          2021               -1           100               2
# 9          2019               -1          9100              23
# ..          ...              ...           ...             ...
# 317        2022               -1             0               0
# 318        2022               -1          3600              17
# 321        2022               -1          2100               7
# 323        2022               -1             0               0
# 324        2022               -1             0               0
#
#      current_balance_avg_sum  current_balance_sum  current_debit_turn_sum  \
# 1                      38000                26800                   56300
# 3                          0                    0                   51500
# 5                      12700                 1000                   15000
# 7                       2700                 4100                   11100
# 9                      32700                50200                  110400
# ..                       ...                  ...                     ...
# 317                     6800                15600                       0
# 318                      400                    0                   11900
# 321                      600                  400                    2100
# 323                     6500               100000                       0
# 324                        0                    0                       0
#
#      current_credit_turn_sum card_type
# 1                      31300        dc
# 3                      51500        cc
# 5                       7800        dc
# 7                      10100        dc
# 9                     151900        dc
# ..                       ...       ...
# 317                    15600        dc
# 318                    11500        dc
# 321                     2000        dc
# 323                   100000        dc
# 324                        0        dc
#
# [7590 rows x 20 columns]

# %%
ValueCardData = ValueCardData.groupby('client_id').agg({'card_type_name':'sum', })
ValueCardData
# Out:
#                                                   card_type_name
# client_id
# 00021cd7b00abc41b066921e5b24e599                    Visa Rewards
# 0005900275b1c05a92710268a0bfdcdd           MasterCard Electronic
# 0020438a8e6c83a5dd7a5a8afdf6188b                       МИР Debit
# 003a838018aa1387ad5103bbcdc2d5e3                       МИР Debit
# 003aba44c70fa03a377f2bec3b871080           Visa Platinum Rewards
# ...                                                          ...
# ffc3ade73ab43964e1418362f8a2576d    Eurocard/MasterCard Platinum
# ffca75257b4148e064882ec897536e0d                    VISA Classic
# ffd07e6797a5d1801cde105327329c46  Дебет карта ПС МИР "Бюджетная"
# ffd64561f67b6d21d85480e59d3563a7           MasterCard Electronic
# fffa15d3b8556f7bebc83f80181a6ffe           Visa Platinum Rewards
#
# [6993 rows x 1 columns]
