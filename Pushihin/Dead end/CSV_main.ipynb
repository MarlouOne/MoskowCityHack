# %%
import pandas as pd

# %%
data = pd.read_csv('Raw_data.csv')
data.isnull().sum()
# Out:
# client_id                       0
# gender                          0
# birth_date                      0
# create_date                     0
# nonresident_flag                0
# businessman_flag                0
# city                         1168
# term                       371583
# contract_sum                    0
# product_category_name           0
# card_id                         0
# card_type_name              52945
# start_date                  52945
# fact_close_date            239407
# purchase_sum                    0
# purchase_count                  0
# current_balance_avg_sum         0
# current_balance_sum             0
# current_debit_turn_sum          0
# current_credit_turn_sum         0
# card_type                       0
# dtype: int64

# %%
data = data.drop(['term','businessman_flag'], axis=1)
data.isnull().sum()
# Out:
# client_id                       0
# gender                          0
# birth_date                      0
# create_date                     0
# nonresident_flag                0
# city                         1168
# contract_sum                    0
# product_category_name           0
# card_id                         0
# card_type_name              52945
# start_date                  52945
# fact_close_date            239407
# purchase_sum                    0
# purchase_count                  0
# current_balance_avg_sum         0
# current_balance_sum             0
# current_debit_turn_sum          0
# current_credit_turn_sum         0
# card_type                       0
# dtype: int64

# %%
data.shape
# Out:
# (371583, 19)

# %%
len(data.card_id.unique())
# Out:
# 22583

# %%
data.card_id.unique()
# Out:
# array(['a83cbc33f164deae41b3339141923cc7',
#        '8dae17a830bb05d151034df618efbcad',
#        '429ca8c43cdc5f3d8c9efc9069ee3fa6', ...,
#        'a78c73e84e893179de17071583cf5084',
#        'e3304eaf55891a175b6abf8030b99da1',
#        'db7d3058f19b8bab645cf33efd86330d'], dtype=object)

# %%
data.query("card_id == 'a83cbc33f164deae41b3339141923cc7'")
# Out:
#                               client_id gender  birth_date create_date  \
# 0      fe60b594364f9f636266ed1ef4f89c32      Ж        1985  2020-01-29
# 18137  fe60b594364f9f636266ed1ef4f89c32      Ж        1985  2020-01-29
# 24097  fe60b594364f9f636266ed1ef4f89c32      Ж        1985  2020-01-29
# 33164  fe60b594364f9f636266ed1ef4f89c32      Ж        1985  2020-01-29
# 41402  fe60b594364f9f636266ed1ef4f89c32      Ж        1985  2020-01-29
# 56111  fe60b594364f9f636266ed1ef4f89c32      Ж        1985  2020-01-29
# 66545  fe60b594364f9f636266ed1ef4f89c32      Ж        1985  2020-01-29
# 71057  fe60b594364f9f636266ed1ef4f89c32      Ж        1985  2020-01-29
# 90683  fe60b594364f9f636266ed1ef4f89c32      Ж        1985  2020-01-29
# 95861  fe60b594364f9f636266ed1ef4f89c32      Ж        1985  2020-01-29
#
#       nonresident_flag              city  contract_sum  \
# 0                    R  Гусь-Хрустальный           0.0
# 18137                R  Гусь-Хрустальный           0.0
# 24097                R  Гусь-Хрустальный           0.0
# 33164                R  Гусь-Хрустальный           0.0
# 41402                R  Гусь-Хрустальный           0.0
# 56111                R  Гусь-Хрустальный           0.0
# 66545                R  Гусь-Хрустальный           0.0
# 71057                R  Гусь-Хрустальный           0.0
# 90683                R  Гусь-Хрустальный           0.0
# 95861                R  Гусь-Хрустальный           0.0
#
#                              product_category_name  \
# 0      Договор на текущий счет для дебетовой карты
# 18137  Договор на текущий счет для дебетовой карты
# 24097  Договор на текущий счет для дебетовой карты
# 33164  Договор на текущий счет для дебетовой карты
# 41402  Договор на текущий счет для дебетовой карты
# 56111  Договор на текущий счет для дебетовой карты
# 66545  Договор на текущий счет для дебетовой карты
# 71057  Договор на текущий счет для дебетовой карты
# 90683  Договор на текущий счет для дебетовой карты
# 95861  Договор на текущий счет для дебетовой карты
#
#                                 card_id         card_type_name  start_date  \
# 0      a83cbc33f164deae41b3339141923cc7  Visa Platinum Rewards      2019.0
# 18137  a83cbc33f164deae41b3339141923cc7  Visa Platinum Rewards      2019.0
# 24097  a83cbc33f164deae41b3339141923cc7  Visa Platinum Rewards      2019.0
# 33164  a83cbc33f164deae41b3339141923cc7  Visa Platinum Rewards      2019.0
# 41402  a83cbc33f164deae41b3339141923cc7  Visa Platinum Rewards      2019.0
# 56111  a83cbc33f164deae41b3339141923cc7  Visa Platinum Rewards      2019.0
# 66545  a83cbc33f164deae41b3339141923cc7  Visa Platinum Rewards      2019.0
# 71057  a83cbc33f164deae41b3339141923cc7  Visa Platinum Rewards      2019.0
# 90683  a83cbc33f164deae41b3339141923cc7  Visa Platinum Rewards      2019.0
# 95861  a83cbc33f164deae41b3339141923cc7  Visa Platinum Rewards      2019.0
#
#        fact_close_date  purchase_sum  purchase_count  current_balance_avg_sum  \
# 0               2021.0       16600.0              71                  39700.0
# 18137           2021.0       41700.0              47                  36900.0
# 24097           2021.0       18100.0              62                  67800.0
# 33164           2021.0       15100.0              55                  81900.0
# 41402           2021.0       25800.0              65                  79300.0
# 56111           2021.0       19200.0              45                  27200.0
# 66545           2021.0       37900.0              87                  39100.0
# 71057           2021.0       30200.0              56                  24300.0
# 90683           2021.0        3900.0              13                    900.0
# 95861           2021.0           0.0               0                      0.0
#
#        current_balance_sum  current_debit_turn_sum  current_credit_turn_sum  \
# 0                  25700.0                220600.0                 201000.0
# 18137              59500.0                 58600.0                  92300.0
# 24097              79600.0                 18200.0                  38300.0
# 33164             106000.0                 33200.0                  59600.0
# 41402              29600.0                126000.0                  49700.0
# 56111              39500.0                 26100.0                  35900.0
# 66545              37100.0                 43300.0                  40900.0
# 71057              22100.0                 53500.0                  38500.0
# 90683                  0.0                128700.0                 106600.0
# 95861                  0.0                     0.0                      0.0
#
#       card_type
# 0            dc
# 18137        dc
# 24097        dc
# 33164        dc
# 41402        dc
# 56111        dc
# 66545        dc
# 71057        dc
# 90683        dc
# 95861        dc

# %%
maxDebet = data.query("card_id == 'a83cbc33f164deae41b3339141923cc7'")['current_debit_turn_sum'].max()
maxDebet
# Out:
# 220600.0

# %%
maxCredet = data.query("card_id == 'a83cbc33f164deae41b3339141923cc7'")['current_credit_turn_sum'].max()
maxCredet
# Out:
# 201000.0

# %%
data.query(f"current_debit_turn_sum == {maxDebet} & current_credit_turn_sum == {maxCredet}")
# Out:
#                           client_id gender  birth_date create_date  \
# 0  fe60b594364f9f636266ed1ef4f89c32      Ж        1985  2020-01-29
#
#   nonresident_flag              city  contract_sum  \
# 0                R  Гусь-Хрустальный           0.0
#
#                          product_category_name  \
# 0  Договор на текущий счет для дебетовой карты
#
#                             card_id         card_type_name  start_date  \
# 0  a83cbc33f164deae41b3339141923cc7  Visa Platinum Rewards      2019.0
#
#    fact_close_date  purchase_sum  purchase_count  current_balance_avg_sum  \
# 0           2021.0       16600.0              71                  39700.0
#
#    current_balance_sum  current_debit_turn_sum  current_credit_turn_sum  \
# 0              25700.0                220600.0                 201000.0
#
#   card_type
# 0        dc

# %%
#listUniqueCardID = data.card_id.unique()

# %%
#import threading

# %%
#def th_get_ActualUserData(gl_DataFrame,listUniqueCardID):
#    for i in range(len(listUniqueCardID)):
#        strPDCall = f"card_id == '{listUniqueCardID[i]}'"
#        maxDebet = data.query(strPDCall)['current_debit_turn_sum'].max()
#        maxCredet = data.query(strPDCall)['current_credit_turn_sum'].max()
##        print(strPDCall)
#        thisDB = data.query(f"current_debit_turn_sum == {maxDebet} & current_credit_turn_sum == {maxCredet}")
#        ActualUserData = pd.concat([ActualUserData, thisDB])

# %%
#ActualUserData = pd.DataFrame()
#
#for i in range(len(listUniqueCardID)):
#    strPDCall = f"card_id == '{listUniqueCardID[i]}'"
#    maxDebet = data.query(strPDCall)['current_debit_turn_sum'].max()
#    maxCredet = data.query(strPDCall)['current_credit_turn_sum'].max()
##    print(strPDCall)
#    thisDB = data.query(f"current_debit_turn_sum == {maxDebet} & current_credit_turn_sum == {maxCredet}")
#    ActualUserData = pd.concat([ActualUserData, thisDB])
#    print(i)
#    
#
#
