# %%
import pandas as pd

# %%
data = pd.read_csv('Raw_data.csv')
data.isnull().sum()
# Out:
# client_id                       0
# gender                          0
# birth_date                      0
# create_date                     0
# nonresident_flag                0
# businessman_flag                0
# city                         1168
# term                       371583
# contract_sum                    0
# product_category_name           0
# card_id                         0
# card_type_name              52945
# start_date                  52945
# fact_close_date            239407
# purchase_sum                    0
# purchase_count                  0
# current_balance_avg_sum         0
# current_balance_sum             0
# current_debit_turn_sum          0
# current_credit_turn_sum         0
# card_type                       0
# dtype: int64

# %%
data = data.drop(['term','businessman_flag'], axis=1)
data.isnull().sum()
# Out:
# client_id                       0
# gender                          0
# birth_date                      0
# create_date                     0
# nonresident_flag                0
# city                         1168
# contract_sum                    0
# product_category_name           0
# card_id                         0
# card_type_name              52945
# start_date                  52945
# fact_close_date            239407
# purchase_sum                    0
# purchase_count                  0
# current_balance_avg_sum         0
# current_balance_sum             0
# current_debit_turn_sum          0
# current_credit_turn_sum         0
# card_type                       0
# dtype: int64

# %%
data.shape
# Out:
# (371583, 19)

# %%
len(data.card_id.unique())
# Out:
# 22583

# %%
data.card_id.unique()
# Out:
# array(['a83cbc33f164deae41b3339141923cc7',
#        '8dae17a830bb05d151034df618efbcad',
#        '429ca8c43cdc5f3d8c9efc9069ee3fa6', ...,
#        'a78c73e84e893179de17071583cf5084',
#        'e3304eaf55891a175b6abf8030b99da1',
#        'db7d3058f19b8bab645cf33efd86330d'], dtype=object)

# %%
data.query("client_id == '135b078a216f3152f7c39c7780a46ba6' & card_type_name == 'VISA Infinite'")
# Out:
#                                client_id gender  birth_date create_date  \
# 8437    135b078a216f3152f7c39c7780a46ba6      М        1951  2010-08-02
# 8440    135b078a216f3152f7c39c7780a46ba6      М        1951  2010-08-02
# 8442    135b078a216f3152f7c39c7780a46ba6      М        1951  2010-08-02
# 13224   135b078a216f3152f7c39c7780a46ba6      М        1951  2010-08-02
# 13227   135b078a216f3152f7c39c7780a46ba6      М        1951  2010-08-02
# ...                                  ...    ...         ...         ...
# 265433  135b078a216f3152f7c39c7780a46ba6      М        1951  2010-08-02
# 265435  135b078a216f3152f7c39c7780a46ba6      М        1951  2010-08-02
# 279348  135b078a216f3152f7c39c7780a46ba6      М        1951  2010-08-02
# 279351  135b078a216f3152f7c39c7780a46ba6      М        1951  2010-08-02
# 279353  135b078a216f3152f7c39c7780a46ba6      М        1951  2010-08-02
#
#        nonresident_flag    city  contract_sum  \
# 8437                  R  Москва         900.0
# 8440                  R  Москва         900.0
# 8442                  R  Москва         900.0
# 13224                 R  Москва         900.0
# 13227                 R  Москва         900.0
# ...                 ...     ...           ...
# 265433                R  Москва         900.0
# 265435                R  Москва         900.0
# 279348                R  Москва         900.0
# 279351                R  Москва         900.0
# 279353                R  Москва         900.0
#
#                               product_category_name  \
# 8437    Договор на текущий счет для дебетовой карты
# 8440    Договор на текущий счет для дебетовой карты
# 8442    Договор на текущий счет для дебетовой карты
# 13224   Договор на текущий счет для дебетовой карты
# 13227   Договор на текущий счет для дебетовой карты
# ...                                             ...
# 265433  Договор на текущий счет для дебетовой карты
# 265435  Договор на текущий счет для дебетовой карты
# 279348  Договор на текущий счет для дебетовой карты
# 279351  Договор на текущий счет для дебетовой карты
# 279353  Договор на текущий счет для дебетовой карты
#
#                                  card_id card_type_name  start_date  \
# 8437    12e5caba2392ff08b1a4a3ff253f3f01  VISA Infinite      2020.0
# 8440    772c9f3817024871f91b9a6c0d4f63aa  VISA Infinite      2021.0
# 8442    f94247c23cd81f55991ad2ce3fa9166b  VISA Infinite      2021.0
# 13224   12e5caba2392ff08b1a4a3ff253f3f01  VISA Infinite      2020.0
# 13227   772c9f3817024871f91b9a6c0d4f63aa  VISA Infinite      2021.0
# ...                                  ...            ...         ...
# 265433  772c9f3817024871f91b9a6c0d4f63aa  VISA Infinite      2021.0
# 265435  f94247c23cd81f55991ad2ce3fa9166b  VISA Infinite      2021.0
# 279348  12e5caba2392ff08b1a4a3ff253f3f01  VISA Infinite      2020.0
# 279351  772c9f3817024871f91b9a6c0d4f63aa  VISA Infinite      2021.0
# 279353  f94247c23cd81f55991ad2ce3fa9166b  VISA Infinite      2021.0
#
#         fact_close_date  purchase_sum  purchase_count  \
# 8437                NaN      159200.0              71
# 8440                NaN      159200.0              71
# 8442                NaN      159200.0              71
# 13224               NaN      100600.0              44
# 13227               NaN      100600.0              44
# ...                 ...           ...             ...
# 265433              NaN       20700.0              24
# 265435              NaN       20700.0              24
# 279348              NaN       13800.0               8
# 279351              NaN       13800.0               8
# 279353              NaN       13800.0               8
#
#         current_balance_avg_sum  current_balance_sum  current_debit_turn_sum  \
# 8437                    69300.0              42000.0                425100.0
# 8440                    69300.0              42000.0                425100.0
# 8442                    69300.0              42000.0                425100.0
# 13224                   39700.0              61200.0                175900.0
# 13227                   39700.0              61200.0                175900.0
# ...                         ...                  ...                     ...
# 265433                  20900.0               1400.0                308500.0
# 265435                  20900.0               1400.0                308500.0
# 279348                  13700.0              46000.0                121900.0
# 279351                  13700.0              46000.0                121900.0
# 279353                  13700.0              46000.0                121900.0
#
#         current_credit_turn_sum card_type
# 8437                   400800.0        dc
# 8440                   400800.0        dc
# 8442                   400800.0        dc
# 13224                  195000.0        dc
# 13227                  195000.0        dc
# ...                         ...       ...
# 265433                 305500.0        dc
# 265435                 305500.0        dc
# 279348                 166500.0        dc
# 279351                 166500.0        dc
# 279353                 166500.0        dc
#
# [72 rows x 19 columns]

# %%
sh = data.query("card_id == '5cfc090a86e988b6b1559ad31ee93b9f'").shape
sh
# Out:
# (24, 19)

# %%
sh[0]
# Out:
# 24

# %%
data.query("card_id == '5cfc090a86e988b6b1559ad31ee93b9f'").drop_duplicates()
# Out:
#                                client_id gender  birth_date create_date  \
# 1811    8c0d527aed779940213eac0ebdf0bcb3      Ж        1994  2012-10-15
# 15727   8c0d527aed779940213eac0ebdf0bcb3      Ж        1994  2012-10-15
# 23000   8c0d527aed779940213eac0ebdf0bcb3      Ж        1994  2012-10-15
# 31881   8c0d527aed779940213eac0ebdf0bcb3      Ж        1994  2012-10-15
# 42877   8c0d527aed779940213eac0ebdf0bcb3      Ж        1994  2012-10-15
# 52245   8c0d527aed779940213eac0ebdf0bcb3      Ж        1994  2012-10-15
# 63503   8c0d527aed779940213eac0ebdf0bcb3      Ж        1994  2012-10-15
# 71101   8c0d527aed779940213eac0ebdf0bcb3      Ж        1994  2012-10-15
# 91682   8c0d527aed779940213eac0ebdf0bcb3      Ж        1994  2012-10-15
# 99698   8c0d527aed779940213eac0ebdf0bcb3      Ж        1994  2012-10-15
# 106674  8c0d527aed779940213eac0ebdf0bcb3      Ж        1994  2012-10-15
# 126909  8c0d527aed779940213eac0ebdf0bcb3      Ж        1994  2012-10-15
# 129755  8c0d527aed779940213eac0ebdf0bcb3      Ж        1994  2012-10-15
# 150272  8c0d527aed779940213eac0ebdf0bcb3      Ж        1994  2012-10-15
# 161070  8c0d527aed779940213eac0ebdf0bcb3      Ж        1994  2012-10-15
# 173935  8c0d527aed779940213eac0ebdf0bcb3      Ж        1994  2012-10-15
# 183407  8c0d527aed779940213eac0ebdf0bcb3      Ж        1994  2012-10-15
# 194762  8c0d527aed779940213eac0ebdf0bcb3      Ж        1994  2012-10-15
# 210850  8c0d527aed779940213eac0ebdf0bcb3      Ж        1994  2012-10-15
#
#        nonresident_flag     city  contract_sum  \
# 1811                  R  Ишимбай           0.0
# 15727                 R  Ишимбай           0.0
# 23000                 R  Ишимбай           0.0
# 31881                 R  Ишимбай           0.0
# 42877                 R  Ишимбай           0.0
# 52245                 R  Ишимбай           0.0
# 63503                 R  Ишимбай           0.0
# 71101                 R  Ишимбай           0.0
# 91682                 R  Ишимбай           0.0
# 99698                 R  Ишимбай           0.0
# 106674                R  Ишимбай           0.0
# 126909                R  Ишимбай           0.0
# 129755                R  Ишимбай           0.0
# 150272                R  Ишимбай           0.0
# 161070                R  Ишимбай           0.0
# 173935                R  Ишимбай           0.0
# 183407                R  Ишимбай           0.0
# 194762                R  Ишимбай           0.0
# 210850                R  Ишимбай           0.0
#
#                               product_category_name  \
# 1811    Договор на текущий счет для дебетовой карты
# 15727   Договор на текущий счет для дебетовой карты
# 23000   Договор на текущий счет для дебетовой карты
# 31881   Договор на текущий счет для дебетовой карты
# 42877   Договор на текущий счет для дебетовой карты
# 52245   Договор на текущий счет для дебетовой карты
# 63503   Договор на текущий счет для дебетовой карты
# 71101   Договор на текущий счет для дебетовой карты
# 91682   Договор на текущий счет для дебетовой карты
# 99698   Договор на текущий счет для дебетовой карты
# 106674  Договор на текущий счет для дебетовой карты
# 126909  Договор на текущий счет для дебетовой карты
# 129755  Договор на текущий счет для дебетовой карты
# 150272  Договор на текущий счет для дебетовой карты
# 161070  Договор на текущий счет для дебетовой карты
# 173935  Договор на текущий счет для дебетовой карты
# 183407  Договор на текущий счет для дебетовой карты
# 194762  Договор на текущий счет для дебетовой карты
# 210850  Договор на текущий счет для дебетовой карты
#
#                                  card_id                  card_type_name  \
# 1811    5cfc090a86e988b6b1559ad31ee93b9f  Дебет карта ПС МИР "Бюджетная"
# 15727   5cfc090a86e988b6b1559ad31ee93b9f  Дебет карта ПС МИР "Бюджетная"
# 23000   5cfc090a86e988b6b1559ad31ee93b9f  Дебет карта ПС МИР "Бюджетная"
# 31881   5cfc090a86e988b6b1559ad31ee93b9f  Дебет карта ПС МИР "Бюджетная"
# 42877   5cfc090a86e988b6b1559ad31ee93b9f  Дебет карта ПС МИР "Бюджетная"
# 52245   5cfc090a86e988b6b1559ad31ee93b9f  Дебет карта ПС МИР "Бюджетная"
# 63503   5cfc090a86e988b6b1559ad31ee93b9f  Дебет карта ПС МИР "Бюджетная"
# 71101   5cfc090a86e988b6b1559ad31ee93b9f  Дебет карта ПС МИР "Бюджетная"
# 91682   5cfc090a86e988b6b1559ad31ee93b9f  Дебет карта ПС МИР "Бюджетная"
# 99698   5cfc090a86e988b6b1559ad31ee93b9f  Дебет карта ПС МИР "Бюджетная"
# 106674  5cfc090a86e988b6b1559ad31ee93b9f  Дебет карта ПС МИР "Бюджетная"
# 126909  5cfc090a86e988b6b1559ad31ee93b9f  Дебет карта ПС МИР "Бюджетная"
# 129755  5cfc090a86e988b6b1559ad31ee93b9f  Дебет карта ПС МИР "Бюджетная"
# 150272  5cfc090a86e988b6b1559ad31ee93b9f  Дебет карта ПС МИР "Бюджетная"
# 161070  5cfc090a86e988b6b1559ad31ee93b9f  Дебет карта ПС МИР "Бюджетная"
# 173935  5cfc090a86e988b6b1559ad31ee93b9f  Дебет карта ПС МИР "Бюджетная"
# 183407  5cfc090a86e988b6b1559ad31ee93b9f  Дебет карта ПС МИР "Бюджетная"
# 194762  5cfc090a86e988b6b1559ad31ee93b9f  Дебет карта ПС МИР "Бюджетная"
# 210850  5cfc090a86e988b6b1559ad31ee93b9f  Дебет карта ПС МИР "Бюджетная"
#
#         start_date  fact_close_date  purchase_sum  purchase_count  \
# 1811        2021.0           2021.0       10900.0              37
# 15727       2021.0           2021.0       10500.0              31
# 23000       2021.0           2021.0       15000.0              23
# 31881       2021.0           2021.0        9100.0              34
# 42877       2021.0           2021.0       20000.0              49
# 52245       2021.0           2021.0        1000.0               4
# 63503       2021.0           2021.0        3100.0              11
# 71101       2021.0           2021.0       11200.0              30
# 91682       2021.0           2021.0        7900.0              24
# 99698       2021.0           2021.0       14700.0              34
# 106674      2021.0           2021.0       18800.0              30
# 126909      2021.0           2021.0       33700.0              34
# 129755      2021.0           2021.0        8400.0              20
# 150272      2021.0           2021.0       16700.0              21
# 161070      2021.0           2021.0       25300.0              70
# 173935      2021.0           2021.0        3600.0              11
# 183407      2021.0           2021.0           0.0               0
# 194762      2021.0           2021.0           0.0               0
# 210850      2021.0           2021.0           0.0               0
#
#         current_balance_avg_sum  current_balance_sum  current_debit_turn_sum  \
# 1811                   110100.0              44500.0                122000.0
# 15727                   23500.0               2300.0                 61800.0
# 23000                    5100.0               1000.0                 18800.0
# 31881                   18800.0              18000.0                 17200.0
# 42877                   16600.0               1300.0                 39000.0
# 52245                   25200.0              33100.0                  3200.0
# 63503                   52900.0              74100.0                 13800.0
# 71101                   71000.0              66700.0                 18900.0
# 91682                   77700.0              80300.0                 25400.0
# 99698                   96100.0             100500.0                 23600.0
# 106674                 105800.0             108200.0                 23500.0
# 126909                 123500.0             117300.0                 33800.0
# 129755                 158100.0             186100.0                 11000.0
# 150272                 192300.0             181000.0                 17500.0
# 161070                 165200.0             143500.0                 43400.0
# 173935                 110700.0             102400.0                 46100.0
# 183407                 102400.0             102400.0                     0.0
# 194762                 102800.0             103400.0                     0.0
# 210850                 103400.0             103400.0                     0.0
#
#         current_credit_turn_sum card_type
# 1811                   107900.0        dc
# 15727                   19700.0        dc
# 23000                   17400.0        dc
# 31881                   34200.0        dc
# 42877                   22300.0        dc
# 52245                   34900.0        dc
# 63503                   54800.0        dc
# 71101                   11500.0        dc
# 91682                   39000.0        dc
# 99698                   43800.0        dc
# 106674                  31300.0        dc
# 126909                  42900.0        dc
# 129755                  79800.0        dc
# 150272                  12400.0        dc
# 161070                   6000.0        dc
# 173935                   4900.0        dc
# 183407                      0.0        dc
# 194762                   1000.0        dc
# 210850                      0.0        dc

# %%
data.query("card_id == '5cfc090a86e988b6b1559ad31ee93b9f'").drop_duplicates().shape
# Out:
# (19, 19)

# %%
maxDebet = data.query("card_id == '5cfc090a86e988b6b1559ad31ee93b9f'")['current_debit_turn_sum'].max()
maxDebet
# Out:
# 122000.0

# %%
maxCredet = data.query("card_id == '5cfc090a86e988b6b1559ad31ee93b9f'")['current_credit_turn_sum'].max()
maxCredet
# Out:
# 107900.0

# %%
data.query(f"current_debit_turn_sum == {maxDebet} & current_credit_turn_sum == {maxCredet}")
# Out:
#                           client_id gender  birth_date create_date  \
# 0  fe60b594364f9f636266ed1ef4f89c32      Ж        1985  2020-01-29
#
#   nonresident_flag              city  contract_sum  \
# 0                R  Гусь-Хрустальный           0.0
#
#                          product_category_name  \
# 0  Договор на текущий счет для дебетовой карты
#
#                             card_id         card_type_name  start_date  \
# 0  a83cbc33f164deae41b3339141923cc7  Visa Platinum Rewards      2019.0
#
#    fact_close_date  purchase_sum  purchase_count  current_balance_avg_sum  \
# 0           2021.0       16600.0              71                  39700.0
#
#    current_balance_sum  current_debit_turn_sum  current_credit_turn_sum  \
# 0              25700.0                220600.0                 201000.0
#
#   card_type
# 0        dc

# %%
#listUniqueCardID = data.card_id.unique()

# %%
#import threading

# %%
#def th_get_ActualUserData(gl_DataFrame,listUniqueCardID):
#    for i in range(len(listUniqueCardID)):
#        strPDCall = f"card_id == '{listUniqueCardID[i]}'"
#        maxDebet = data.query(strPDCall)['current_debit_turn_sum'].max()
#        maxCredet = data.query(strPDCall)['current_credit_turn_sum'].max()
##        print(strPDCall)
#        thisDB = data.query(f"current_debit_turn_sum == {maxDebet} & current_credit_turn_sum == {maxCredet}")
#        ActualUserData = pd.concat([ActualUserData, thisDB])

# %%
#ActualUserData = pd.DataFrame()
#
#for i in range(len(listUniqueCardID)):
#    strPDCall = f"card_id == '{listUniqueCardID[i]}'"
#    maxDebet = data.query(strPDCall)['current_debit_turn_sum'].max()
#    maxCredet = data.query(strPDCall)['current_credit_turn_sum'].max()
##    print(strPDCall)
#    thisDB = data.query(f"current_debit_turn_sum == {maxDebet} & current_credit_turn_sum == {maxCredet}")
#    ActualUserData = pd.concat([ActualUserData, thisDB])
#    print(i)
#    
#
#
